# %%
import json
import pandas as pd

with open('../data/summaries_1k.json', 'r', encoding='utf-8') as f:
    json_data = json.load(f)

data = json_data['data']
url_count = json_data['url_count']

df = pd.json_normalize(data)

print(f"Loaded {len(df)} records")
print(f"Total URLs: {url_count}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nDataFrame shape: {df.shape}")
print(f"\nFirst few rows:")
df.head()
# Out:
# Loaded 1000 records
# Total URLs: 1000
#
# Columns: ['url', 'markdown_content', 'summary']
#
# DataFrame shape: (1000, 3)
#
# First few rows:
#                                                  url  \
# 0         https://www.microsoft.com/wdsi/definitions
# 1  https://learn.microsoft.com/en-us/defender-end...
# 2  https://www.reddit.com/r/SCCM/comments/1954ghr...
# 3  https://www.catalog.update.microsoft.com/Searc...
# 4  https://answers.microsoft.com/en-us/windows/fo...
#
#                                     markdown_content  \
# 0  Latest security intelligence updates for Micro...
# 1  Microsoft Defender Antivirus security intellig...
# 2  Reddit - The heart of the internet\n\n========...
# 3  Microsoft Update Catalog\n\n===============\n\...
# 4  KB2267602 continually wanting to update - Micr...
#
#                                              summary
# 0  Latest security intelligence updates for Micro...
# 1  Microsoft Defender Antivirus security intellig...
# 2  Reddit - The heart of the internet Image 1: r/...
# 3  Microsoft®Update CatalogFAQ|helpImage 1Image 2...
# 4  KB2267602 continually wanting to update - Micr...
